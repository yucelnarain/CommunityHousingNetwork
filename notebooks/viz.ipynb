# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

st.title('Uber pickups in NYC')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
df = pd.DataFrame(
     np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
     columns=['lat', 'lon'])
df
# Out:
#            lat         lon
# 0    37.743836 -122.373488
# 1    37.784915 -122.412948
# 2    37.751051 -122.411058
# 3    37.769691 -122.442478
# 4    37.714466 -122.405668
# ..         ...         ...
# 995  37.768621 -122.425629
# 996  37.803501 -122.390154
# 997  37.769982 -122.392079
# 998  37.767906 -122.381086
# 999  37.771311 -122.446555
#
# [1000 rows x 2 columns]

# %%
df1 = pd.read_csv('ACSDT1Y2019.B25070-2022-01-21T214228.csv')
df1
# Out:
#               Label (Grouping) Macomb County, Michigan!!Estimate  \
# 0                       Total:                            90,873
# 1       Less than 10.0 percent                             2,977
# 2         10.0 to 14.9 percent                             8,826
# 3         15.0 to 19.9 percent                             9,347
# 4         20.0 to 24.9 percent                            13,260
# 5         25.0 to 29.9 percent                             8,770
# 6         30.0 to 34.9 percent                             7,973
# 7         35.0 to 39.9 percent                             5,387
# 8         40.0 to 49.9 percent                             8,087
# 9         50.0 percent or more                            21,424
# 10                Not computed                             4,822
#
#    Macomb County, Michigan!!Margin of Error  \
# 0                                    ±4,226
# 1                                      ±770
# 2                                    ±1,526
# 3                                    ±1,659
# 4                                    ±2,035
# 5                                    ±1,519
# 6                                    ±1,453
# 7                                    ±1,152
# 8                                    ±1,767
# 9                                    ±2,456
# 10                                   ±1,067
#
#    Oakland County, Michigan!!Estimate  \
# 0                             144,148
# 1                               6,537
# 2                              16,877
# 3                              21,854
# 4                              19,016
# 5                              14,884
# 6                              10,196
# 7                               7,535
# 8                               9,901
# 9                              30,776
# 10                              6,572
#
#    Oakland County, Michigan!!Margin of Error Wayne County, Michigan!!Estimate  \
# 0                                     ±5,615                          258,350
# 1                                     ±1,267                            9,867
# 2                                     ±2,291                           24,110
# 3                                     ±2,825                           25,690
# 4                                     ±2,350                           25,246
# 5                                     ±2,138                           26,105
# 6                                     ±1,804                           20,800
# 7                                     ±1,561                           15,383
# 8                                     ±1,750                           20,048
# 9                                     ±2,716                           69,244
# 10                                    ±1,435                           21,857
#
#    Wayne County, Michigan!!Margin of Error
# 0                                   ±7,305
# 1                                   ±1,646
# 2                                   ±2,813
# 3                                   ±2,533
# 4                                   ±2,763
# 5                                   ±2,957
# 6                                   ±2,445
# 7                                   ±2,340
# 8                                   ±2,115
# 9                                   ±4,371
# 10                                  ±3,168

# %%
county_option = 'Macomb'
if county_option == 'Macomb':
    county_filter = "Macomb County, Michigan!!Estimate"
elif county_option == 'Oakland':
    county_filter = "Oakland County, Michigan!!Estimate"
else:
    county_filter = "Wayne County, Michigan!!Estimate"

df1[county_filter][1:]
# Out:
# 1      2,977
# 2      8,826
# 3      9,347
# 4     13,260
# 5      8,770
# 6      7,973
# 7      5,387
# 8      8,087
# 9     21,424
# 10     4,822
# Name: Macomb County, Michigan!!Estimate, dtype: object

# %%
def strip(input):
    output = input.replace(",","")
    return int(output)

hist_values = df1[county_filter][1:].apply(strip)
hist_values


labels = df1['Label (Grouping)'][1:]
fig, ax = plt.subplots()
ax.bar(labels, hist_values)
plt.xticks(rotation = 'vertical')
st.pyplot(fig)
# Out:
# 1      2977
# 2      8826
# 3      9347
# 4     13260
# 5      8770
# 6      7973
# 7      5387
# 8      8087
# 9     21424
# 10     4822
# Name: Macomb County, Michigan!!Estimate, dtype: int64

# %%
y = '5,387'

y = y.replace(",","")
print(y)
# Out:
# 5387
